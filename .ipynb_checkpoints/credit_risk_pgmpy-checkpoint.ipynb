# %% [markdown]
# # Importación de módulos generales

# %%
# %pylab inline
# %load_ext memory_profiler

# %pylab

import os
import tempfile
import pandas as pd
# import numpy as np
import networkx as nx
# import matplotlib
# import pylab  as plt
import pygraphviz

from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Funciones auxiliares visualización

# %% [markdown]
# Importamos las funciones auxiliares para visualizar redes que hemos definido:
# - **plot_pomegranate_bn_nx**(pgm, layout=None, node_size=2000, node_color='pink')
# - **plot_pomegranate_bn_pgvz**(pgm, filename=None, prog='dot', color='red')
# - **plot_pgmpy_bn**(pgm, layout=None, node_size=2000, node_color='pink'):

# %%
from funciones_auxiliares import *

# %% [markdown]
# # Lectura de datos

# %% [markdown]
# Podemos obtener los datos originales de http://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data.
#
# Sin embargo, los valores de las variables no son muy descriptivos así que cargamos los datos convertidos a un formato más descriptivo de https://weka.8497.n7.nabble.com/file/n23121/credit_fruad.arff y convertidos a csv:

# %%
data = pd.read_csv("data/credit_risk/german_credit_data_weka.csv", index_col=0)
data.head()
# Out:
#                credit_usage                    credit_history  \
# over_draft
# <0                        6  'critical/other existing credit'
# 0<=X<200                 48                   'existing paid'
# 'no checking'            12  'critical/other existing credit'
# <0                       42                   'existing paid'
# <0                       24              'delayed previously'
#
#                            purpose  current_balance Average_Credit_Balance  \
# over_draft
# <0                        radio/tv             1169     'no known savings'
# 0<=X<200                  radio/tv             5951                   <100
# 'no checking'            education             2096                   <100
# <0             furniture/equipment             7882                   <100
# <0                       'new car'             4870                   <100
#
#               employment  location       personal_status other_parties  \
# over_draft
# <0                   >=7         4         'male single'          none
# 0<=X<200          1<=X<4         2  'female div/dep/mar'          none
# 'no checking'     4<=X<7         2         'male single'          none
# <0                4<=X<7         2         'male single'     guarantor
# <0                1<=X<4         3         'male single'          none
#
#                residence_since   property_magnitude  cc_age  \
# over_draft
# <0                           4        'real estate'      67
# 0<=X<200                     2        'real estate'      22
# 'no checking'                3        'real estate'      49
# <0                           4     'life insurance'      45
# <0                           4  'no known property'      53
#
#               other_payment_plans     housing  existing_credits  \
# over_draft
# <0                           none         own                 2
# 0<=X<200                     none         own                 1
# 'no checking'                none         own                 1
# <0                           none  'for free'                 1
# <0                           none  'for free'                 2
#
#                                 job  num_dependents own_telephone  \
# over_draft
# <0                          skilled               1           yes
# 0<=X<200                    skilled               1          none
# 'no checking'  'unskilled resident'               2          none
# <0                          skilled               2          none
# <0                          skilled               2          none
#
#               foreign_worker class
# over_draft
# <0                       yes  good
# 0<=X<200                 yes   bad
# 'no checking'            yes  good
# <0                       yes  good
# <0                       yes   bad

# %% [markdown]
# Como vemos no hay valores nulos en nuestro dataset:

# %%
print(data.isnull().sum())
# Out:
# credit_usage              0
# credit_history            0
# purpose                   0
# current_balance           0
# Average_Credit_Balance    0
# employment                0
# location                  0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# cc_age                    0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %% [markdown]
# Discretizamos las variables numéricas:

# %%
columns_to_discretize = ['credit_usage', 'current_balance', 'cc_age']
num_bins=20

for col in columns_to_discretize:
    data[col] = pd.cut(data[col], bins=num_bins)
    
data.head()
# Out:
#                credit_usage                    credit_history  \
# over_draft
# <0             (3.932, 7.4]  'critical/other existing credit'
# 0<=X<200       (44.8, 48.2]                   'existing paid'
# 'no checking'  (10.8, 14.2]  'critical/other existing credit'
# <0             (41.4, 44.8]                   'existing paid'
# <0             (21.0, 24.4]              'delayed previously'
#
#                            purpose   current_balance Average_Credit_Balance  \
# over_draft
# <0                        radio/tv  (1158.7, 2067.4]     'no known savings'
# 0<=X<200                  radio/tv  (5702.2, 6610.9]                   <100
# 'no checking'            education  (2067.4, 2976.1]                   <100
# <0             furniture/equipment  (7519.6, 8428.3]                   <100
# <0                       'new car'  (4793.5, 5702.2]                   <100
#
#               employment  location       personal_status other_parties  \
# over_draft
# <0                   >=7         4         'male single'          none
# 0<=X<200          1<=X<4         2  'female div/dep/mar'          none
# 'no checking'     4<=X<7         2         'male single'          none
# <0                4<=X<7         2         'male single'     guarantor
# <0                1<=X<4         3         'male single'          none
#
#                residence_since   property_magnitude        cc_age  \
# over_draft
# <0                           4        'real estate'  (66.6, 69.4]
# 0<=X<200                     2        'real estate'  (21.8, 24.6]
# 'no checking'                3        'real estate'  (47.0, 49.8]
# <0                           4     'life insurance'  (44.2, 47.0]
# <0                           4  'no known property'  (52.6, 55.4]
#
#               other_payment_plans     housing  existing_credits  \
# over_draft
# <0                           none         own                 2
# 0<=X<200                     none         own                 1
# 'no checking'                none         own                 1
# <0                           none  'for free'                 1
# <0                           none  'for free'                 2
#
#                                 job  num_dependents own_telephone  \
# over_draft
# <0                          skilled               1           yes
# 0<=X<200                    skilled               1          none
# 'no checking'  'unskilled resident'               2          none
# <0                          skilled               2          none
# <0                          skilled               2          none
#
#               foreign_worker class
# over_draft
# <0                       yes  good
# 0<=X<200                 yes   bad
# 'no checking'            yes  good
# <0                       yes  good
# <0                       yes   bad

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y validación

# %%
complete_data = data

X_complete = complete_data.drop(columns=['class'])
y_complete = complete_data['class']

X_complete_train, X_complete_test, y_complete_train, y_complete_test = train_test_split(X_complete, y_complete, test_size=1/3)

print("\nParticiones obtenidas sobre los datos:")
print("X_complete_train: ", X_complete_train.shape)
print("y_complete_train: ", y_complete_train.shape)
print("X_complete_test:  ", X_complete_test.shape)
print("y_complete_test:  ", y_complete_test.shape)
# Out:
# Particiones obtenidas sobre los datos:
# X_complete_train:  (666, 19)
# y_complete_train:  (666,)
# X_complete_test:   (334, 19)
# y_complete_test:   (334,)

# %% [markdown]
# # Algoritmos de búsqueda global

# %%
from pgmpy.models import BayesianModel

# %% [markdown]
# Definición de scores sobre el dataset:

# %%
from pgmpy.estimators import BDeuScore, K2Score, BicScore

bdeu = BDeuScore(complete_data, equivalent_sample_size=5)
k2 = K2Score(complete_data)
bic = BicScore(complete_data)

# %% [markdown]
# Si quisieramos usar un algoritmo exacto, tendriamos que iterar sobre los $2^{N(N-1)}$ siendo N el número de nodos, es decir:

# %%
N=len(list(complete_data))
print("Número de DAGs posibles con N={} ---> {}".format(N, 2**(N*(N-1))))
# Out:
# Número de DAGs posibles con N=20 ---> 2462625387274654950767440006258975862817483704404090416746768337765357610718575663213391640930307227550414249394176

# %%
# from pgmpy.estimators import ExhaustiveSearch

# # Definición algoritmos de búsqueda exactos con cada score
# es_bic = ExhaustiveSearch(complete_data, scoring_method=bic)
# es_k2 = ExhaustiveSearch(complete_data, scoring_method=k2)
# es_bdeu = ExhaustiveSearch(complete_data, scoring_method=bdeu)

# # Aprendizaje de las redes
# print("Exhaustive search BIC:")
# %time %memit es_bic_structure = es_bic.estimate()
# print("Exhaustive search K2:")
# %time %memit es_k2_structurel = es_k2.estimate()
# print("Exhaustive search BDeu:")
# %time %memit es_bdeu_structure = es_bdeu.estimate()

# %% [markdown]
# Así que vamos a usar Hill Climb Search:

# %%
from pgmpy.estimators import HillClimbSearch

hc_bic = HillClimbSearch(data, scoring_method=bic)
hc_k2 = HillClimbSearch(data, scoring_method=k2)
hc_bdeu = HillClimbSearch(data, scoring_method=bdeu)

# Aprendizaje de las redes
print("Hill Climb Search BIC:")
# %time %memit hc_bic_structure = hc_bic.estimate()
print("\nHill Climb Search K2:")
# %time %memit hc_k2_structure = hc_k2.estimate()
print("\nHill Climb Search BDeu:")
# %time %memit hc_bdeu_structure = hc_bdeu.estimate()
# Out:
# Hill Climb Search BIC:
# peak memory: 213.29 MiB, increment: 25.75 MiB
# Wall time: 1min 44s
#
# Hill Climb Search K2:
# peak memory: 315.83 MiB, increment: 102.54 MiB
# Wall time: 22min 8s
#
# Hill Climb Search BDeu:
# peak memory: 260.21 MiB, increment: 28.02 MiB
# Wall time: 2min 31s
# Compiler : 141 ms

# %% [markdown]
# Visualizamos los modelos resultantes:

# %%
print("Hill Climb Search BIC:")
plot_pgmpy_bn(hc_bic_structure)
# Out:
# Hill Climb Search BIC:

# %%
print("\nHill Climb Search K2:")
plot_pgmpy_bn(hc_k2_structure)
# Out:
# Hill Climb Search K2:

# %%
print("\nHill Climb Search BDeu:")
plot_pgmpy_bn(hc_bdeu_structure)
# Out:
# Hill Climb Search BDeu:

# %% [markdown]
# A la hora de estimar, podemos indicar el número máximo de padres por variable. Por ejemplo, si exigimos que sea 1, aprenderemos estructuras de árbol y el aprendizaje será más rápido:

# %%
print("Hill Climb Search BIC tree:")
# %time %memit hc_bic_tree = hc_bic.estimate(max_indegree=1)
print("\nHill Climb Search K2 tree:")
# %time %memit hc_k2_tree = hc_k2.estimate(max_indegree=1)
print("\nHill Climb Search BDeu tree:")
# %time %memit hc_bdeu_tree = hc_bdeu.estimate(max_indegree=1)
# Out:
# Hill Climb Search BIC:
# peak memory: 275.46 MiB, increment: 1.61 MiB
# Wall time: 50.3 s
#
# Hill Climb Search K2:
# peak memory: 275.86 MiB, increment: 0.40 MiB
# Wall time: 31.1 s
#
# Hill Climb Search BDeu:
# peak memory: 275.85 MiB, increment: 0.00 MiB
# Wall time: 37.7 s

# %%
print("Hill Climb Search BIC tree:")
plot_pgmpy_bn(hc_bic_tree, layout='graphviz', node_size=1000)
# Out:
# Hill Climb Search BIC tree:

# %%
print("\nHill Climb Search K2 tree:")
plot_pgmpy_bn(hc_k2_tree, layout='graphviz', node_size=1000)
# Out:
# Hill Climb Search K2 tree:

# %%
print("\nHill Climb Search BDeu tree:")
plot_pgmpy_bn(hc_bdeu_tree, layout='graphviz', node_size=1000)
# Out:
# Hill Climb Search BDeu tree:

# %% [markdown]
# # Algoritmos locales mediante tests de independencia

# %%
from pgmpy.estimators import ConstraintBasedEstimator

constraint_estimator = ConstraintBasedEstimator(data)

print("Constraint Estimation:")
# %time %memit constraint_structure = constraint_estimator.estimate(significance_level=0.01)
# Out:
# Constraint Estimation:
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | []. At least 1350.0 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ cc_age | []. At least 1425.0 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | []. At least 1350.0 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ cc_age | []. At least 1710.0 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ credit_history | ['location']. At least 1200 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ purpose | ['location']. At least 2700 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | ['location']. At least 5400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | ['class']. At least 2700 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | ['own_telephone']. At least 2700 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | ['foreign_worker']. At least 2700 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ current_balance | ['property_magnitude']. At least 5400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ property_magnitude | ['current_balance']. At least 4275 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ own_telephone | ['current_balance']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ foreign_worker | ['current_balance']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing credit_usage _|_ class | ['current_balance']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['personal_status']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['property_magnitude']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['own_telephone']. At least 1620 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['housing']. At least 2430 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['job']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ current_balance | ['other_parties']. At least 2430 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing purpose _|_ job | ['current_balance']. At least 2565 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['location']. At least 5400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['property_magnitude']. At least 5400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['own_telephone']. At least 2700 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['purpose']. At least 13500 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['housing']. At least 4050 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ credit_usage | ['job']. At least 5400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['location']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['property_magnitude']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['own_telephone']. At least 1620 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['housing']. At least 2430 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['job']. At least 3240 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ purpose | ['credit_usage']. At least 12960 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ location | ['property_magnitude']. At least 1080 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ property_magnitude | ['credit_usage']. At least 4320 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ job | ['credit_usage']. At least 4320 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing current_balance _|_ own_telephone | ['credit_usage']. At least 1440 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ residence_since | ['cc_age']. At least 1200 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ property_magnitude | ['cc_age']. At least 1200 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ cc_age | ['existing_credits']. At least 1520 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ cc_age | ['job']. At least 1520 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ cc_age | ['housing']. At least 1140 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing employment _|_ job | ['cc_age']. At least 1200 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing cc_age _|_ employment | ['residence_since']. At least 1520 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing cc_age _|_ employment | ['housing']. At least 1140 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing cc_age _|_ employment | ['job']. At least 1520 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing cc_age _|_ residence_since | ['employment']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing cc_age _|_ job | ['employment']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing job _|_ employment | ['cc_age']. At least 1200 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing job _|_ cc_age | ['employment']. At least 1425 samples recommended, 1000 present.
#   5 * num_params, len(data)
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\pgmpy\estimators\CITests.py:95: UserWarning: Insufficient data for testing job _|_ employment | ['cc_age', 'own_telephone']. At least 2400 samples recommended, 1000 present.
#   5 * num_params, len(data)
# peak memory: 278.48 MiB, increment: 1.82 MiB
# Wall time: 1min 16s

# %%
print("Constraint Estimation:")
plot_pgmpy_bn(constraint_structure)
# Out:
# Constraint Estimation:

# %% [markdown]
# # Aprendizaje de parámetros

# %% [markdown]
# Vamos a quedarnos, por ejemplo, con la red aprendida usando *Hill Climb Search* y como score *Bdeu*

# %%
from pgmpy.models import BayesianModel

hc_bdeu_model = BayesianModel()
hc_bdeu_model.add_nodes_from(hc_bdeu_structure.nodes)
hc_bdeu_model.add_edges_from(hc_bdeu_structure.edges)

# %% [markdown]
# Podemos obtener el recuento de las apariciones de las distintas variables

# %%
from pgmpy.estimators import ParameterEstimator

pe = ParameterEstimator(hc_bdeu_model, data)
print(pe.state_counts('existing_credits'))
# Out:
# num_dependents      1   2
# existing_credits
# 1                 550  83
# 2                 273  60
# 3                  18  10
# 4                   4   2

# %% [markdown]
# O directamente las probabilidades usando un estimador máximo verosimil, que en este caso se corresponde a las frecuencias relativas

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
mle = MaximumLikelihoodEstimator(hc_bdeu_model, data)
print(mle.estimate_cpd('existing_credits'))
# Out:
# +---------------------+----------------------+----------------------+
# | num_dependents      | num_dependents(1)    | num_dependents(2)    |
# +---------------------+----------------------+----------------------+
# | existing_credits(1) | 0.650887573964497    | 0.535483870967742    |
# +---------------------+----------------------+----------------------+
# | existing_credits(2) | 0.3230769230769231   | 0.3870967741935484   |
# +---------------------+----------------------+----------------------+
# | existing_credits(3) | 0.021301775147928994 | 0.06451612903225806  |
# +---------------------+----------------------+----------------------+
# | existing_credits(4) | 0.004733727810650888 | 0.012903225806451613 |
# +---------------------+----------------------+----------------------+

# %% [markdown]
# Para obtener todas las TPC a la vez:

# %%
hc_bdeu_model.fit(data, estimator=MaximumLikelihoodEstimator)
# Out:
# WARNING:root:Replacing existing CPD for Average_Credit_Balance
# WARNING:root:Replacing existing CPD for cc_age
# WARNING:root:Replacing existing CPD for class
# WARNING:root:Replacing existing CPD for credit_history
# WARNING:root:Replacing existing CPD for credit_usage
# WARNING:root:Replacing existing CPD for current_balance
# WARNING:root:Replacing existing CPD for employment
# WARNING:root:Replacing existing CPD for existing_credits
# WARNING:root:Replacing existing CPD for foreign_worker
# WARNING:root:Replacing existing CPD for housing
# WARNING:root:Replacing existing CPD for job
# WARNING:root:Replacing existing CPD for location
# WARNING:root:Replacing existing CPD for num_dependents
# WARNING:root:Replacing existing CPD for other_parties
# WARNING:root:Replacing existing CPD for other_payment_plans
# WARNING:root:Replacing existing CPD for own_telephone
# WARNING:root:Replacing existing CPD for personal_status
# WARNING:root:Replacing existing CPD for property_magnitude
# WARNING:root:Replacing existing CPD for purpose
# WARNING:root:Replacing existing CPD for residence_since

# %% [markdown]
# Podemos usar estimadores bayesianos, suponiendo una distribucióna  priori:

# %%
from pgmpy.estimators import BayesianEstimator

est = BayesianEstimator(hc_bdeu_model, data)
print(est.estimate_cpd('existing_credits', prior_type='BDeu', equivalent_sample_size=10))

hc_bdeu_model.fit(data, estimator=BayesianEstimator, prior_type="BDeu") # default equivalent_sample_size=5
# Out:
# +---------------------+----------------------+-------------------+
# | num_dependents      | num_dependents(1)    | num_dependents(2) |
# +---------------------+----------------------+-------------------+
# | existing_credits(1) | 0.6485294117647059   | 0.5265625         |
# +---------------------+----------------------+-------------------+
# | existing_credits(2) | 0.3226470588235294   | 0.3828125         |
# +---------------------+----------------------+-------------------+
# | existing_credits(3) | 0.022647058823529412 | 0.0703125         |
# +---------------------+----------------------+-------------------+
# | existing_credits(4) | 0.006176470588235294 | 0.0203125         |
# +---------------------+----------------------+-------------------+
# WARNING:root:Replacing existing CPD for credit_usage
# WARNING:root:Replacing existing CPD for credit_history
# WARNING:root:Replacing existing CPD for purpose
# WARNING:root:Replacing existing CPD for current_balance
# WARNING:root:Replacing existing CPD for Average_Credit_Balance
# WARNING:root:Replacing existing CPD for employment
# WARNING:root:Replacing existing CPD for location
# WARNING:root:Replacing existing CPD for personal_status
# WARNING:root:Replacing existing CPD for other_parties
# WARNING:root:Replacing existing CPD for residence_since
# WARNING:root:Replacing existing CPD for property_magnitude
# WARNING:root:Replacing existing CPD for cc_age
# WARNING:root:Replacing existing CPD for other_payment_plans
# WARNING:root:Replacing existing CPD for housing
# WARNING:root:Replacing existing CPD for existing_credits
# WARNING:root:Replacing existing CPD for job
# WARNING:root:Replacing existing CPD for num_dependents
# WARNING:root:Replacing existing CPD for own_telephone
# WARNING:root:Replacing existing CPD for foreign_worker
# WARNING:root:Replacing existing CPD for class

# %% [markdown]
# Vemos como las probabilidades que antes eran 0 ahora no lo son

# %% [markdown]
# # Comparación accuracy distintas estructuras

# %% [markdown]
# Creamos los modelos a partir de las estructuras:

# %%
from pgmpy.models import BayesianModel

hc_bdeu_model = BayesianModel()
hc_bdeu_model.add_nodes_from(hc_bdeu_structure.nodes)
hc_bdeu_model.add_edges_from(hc_bdeu_structure.edges)

hc_k2_model = BayesianModel()
hc_k2_model.add_nodes_from(hc_k2_structure.nodes)
hc_k2_model.add_edges_from(hc_k2_structure.edges)

hc_bic_model = BayesianModel()
hc_bic_model.add_nodes_from(hc_bic_structure.nodes)
hc_bic_model.add_edges_from(hc_bic_structure.edges)

constraint_model = BayesianModel()
constraint_model.add_nodes_from(constraint_structure.nodes)
constraint_model.add_edges_from(constraint_structure.edges)

# %% [markdown]
# Estimamos los parámetros usando un estimador bayesiano con priori uniforme:

# %%
from pgmpy.estimators import BayesianEstimator

hc_bdeu_model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
hc_k2_model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
hc_bic_model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
constraint_model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")

# %% [markdown]
# Preparamos la inferencia con eliminación de variables:

# %%
from pgmpy.inference import VariableElimination

hc_bdeu_inference = VariableElimination(hc_bdeu_model)
hc_k2_inference = VariableElimination(hc_k2_model)
hc_bic_inference = VariableElimination(hc_bic_model)
constraint_inference = VariableElimination(constraint_model)

# %% [markdown]
# Ejecutamos la inferencia:

# %%
# X_complete_train_dict = list(X_complete_train.to_dict('index').values())

# %time %memit y_pred_hc_bdeu = [hc_bdeu_inference.map_query(variables=['Outcome'], evidence=entry, elimination_order='MinFill', \
#                     show_progress=False)['Outcome'] for entry in X_complete_train_dict]
# %time %memit y_pred_hc_k2 = [hc_k2_inference.map_query(variables=['Outcome'], evidence=entry, elimination_order='MinFill', \
#                     show_progress=False)['Outcome'] for entry in X_complete_train_dict]
# %time %memit y_pred_hc_bic = [hc_bic_inference.map_query(variables=['Outcome'], evidence=entry, elimination_order='MinFill', \
#                     show_progress=False)['Outcome'] for entry in X_complete_train_dict]
# %time %memit y_pred_constraint = [constraint_inference.map_query(variables=['Outcome'], evidence=entry, elimination_order='MinFill', \
#                         show_progress=False)['Outcome'] for entry in X_complete_train_dict]

# # for entry in X_complete_train_dict:
#     print(hc_bdeu_inference.map_query(variables=['Outcome'], evidence=entry, elimination_order='MinFill')['Outcome'])
# hc_bdeu_inference.map_query(variables=['Outcome'], evidence=None, elimination_order='MinFill')

# %% [markdown]
# O más facil:

# %%
# %time %memit y_pred_hc_bdeu = hc_bdeu_model.predict(X_complete_train)
# %time %memit y_pred_hc_k2 = hc_k2_model.predict(X_complete_train)
# %time %memit y_pred_hc_bic = hc_bic_model.predict(X_complete_train)
# %time %memit y_pred_constraint = constraint_model.predict(X_complete_train)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 665/665 [00:16<00:00, 39.28it/s]
# peak memory: 280.91 MiB, increment: 1.49 MiB
# Wall time: 18.9 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 665/665 [00:29<00:00, 22.23it/s]
# peak memory: 281.18 MiB, increment: 0.26 MiB
# Wall time: 31.8 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 665/665 [00:07<00:00, 93.96it/s]
# peak memory: 281.03 MiB, increment: 0.02 MiB
# Wall time: 8.93 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 665/665 [00:13<00:00, 50.80it/s]
# peak memory: 281.04 MiB, increment: 0.03 MiB
# Wall time: 14.6 s

# %%
print("HC BDeu:\n", classification_report(list(y_pred_hc_bdeu['class']), list(y_complete_train)))
print("HC K2:\n", classification_report(list(y_pred_hc_k2['class']), list(y_complete_train)))
print("HC BIC:\n", classification_report(list(y_pred_hc_bic['class']), list(y_complete_train)))
print("Constraint:\n", classification_report(list(y_pred_constraint['class']), list(y_complete_train)))
# Out:
# HC BDeu:
#                precision    recall  f1-score   support
#
#          bad       0.16      0.68      0.26        47
#         good       0.97      0.72      0.83       619
#
#     accuracy                           0.72       666
#    macro avg       0.56      0.70      0.54       666
# weighted avg       0.91      0.72      0.79       666
#
# HC K2:
#                precision    recall  f1-score   support
#
#          bad       0.32      0.65      0.42        99
#         good       0.92      0.75      0.83       567
#
#     accuracy                           0.74       666
#    macro avg       0.62      0.70      0.63       666
# weighted avg       0.83      0.74      0.77       666
#
# HC BIC:
#                precision    recall  f1-score   support
#
#          bad       0.16      0.68      0.26        47
#         good       0.97      0.72      0.83       619
#
#     accuracy                           0.72       666
#    macro avg       0.56      0.70      0.54       666
# weighted avg       0.91      0.72      0.79       666
#
# Constraint:
#                precision    recall  f1-score   support
#
#          bad       0.00      0.00      0.00         0
#         good       1.00      0.70      0.82       666
#
#     accuracy                           0.70       666
#    macro avg       0.50      0.35      0.41       666
# weighted avg       1.00      0.70      0.82       666
# C:\Users\usuario\.conda\envs\PGM\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Sobre los datos de validación:

# %%
# %time %memit y_pred_hc_bdeu = hc_bdeu_model.predict(X_complete_test)
# %time %memit y_pred_hc_k2 = hc_k2_model.predict(X_complete_test)
# %time %memit y_pred_hc_bic = hc_bic_model.predict(X_complete_test)
# %time %memit y_pred_constraint = constraint_model.predict(X_complete_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 334/334 [00:05<00:00, 57.64it/s]
# peak memory: 281.15 MiB, increment: 0.07 MiB
# Wall time: 7.2 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 334/334 [00:12<00:00, 26.22it/s]
# peak memory: 281.16 MiB, increment: 0.02 MiB
# Wall time: 14.7 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 334/334 [00:03<00:00, 89.71it/s]
# peak memory: 281.16 MiB, increment: 0.02 MiB
# Wall time: 5.26 s
# 100%|████████████████████████████████████████████████████████████████████████████████| 334/334 [00:06<00:00, 52.66it/s]
# peak memory: 281.16 MiB, increment: 0.02 MiB
# Wall time: 7.89 s

# %%
print("HC BDeu:\n", classification_report(list(y_pred_hc_bdeu['class']), list(y_complete_test)))
print("HC K2:\n", classification_report(list(y_pred_hc_k2['class']), list(y_complete_test)))
print("HC BIC:\n", classification_report(list(y_pred_hc_bic['class']), list(y_complete_test)))
print("Constraint:\n", classification_report(list(y_pred_constraint['class']), list(y_complete_test)))
# Out:
# HC BDeu:
#                precision    recall  f1-score   support
#
#          bad       0.15      0.71      0.25        21
#         good       0.97      0.74      0.84       313
#
#     accuracy                           0.74       334
#    macro avg       0.56      0.73      0.55       334
# weighted avg       0.92      0.74      0.80       334
#
# HC K2:
#                precision    recall  f1-score   support
#
#          bad       0.34      0.75      0.47        44
#         good       0.95      0.78      0.86       290
#
#     accuracy                           0.78       334
#    macro avg       0.65      0.76      0.66       334
# weighted avg       0.87      0.78      0.81       334
#
# HC BIC:
#                precision    recall  f1-score   support
#
#          bad       0.15      0.71      0.25        21
#         good       0.97      0.74      0.84       313
#
#     accuracy                           0.74       334
#    macro avg       0.56      0.73      0.55       334
# weighted avg       0.92      0.74      0.80       334
#
# Constraint:
#                precision    recall  f1-score   support
#
#          bad       0.00      0.00      0.00         0
#         good       1.00      0.71      0.83       334
#
#     accuracy                           0.71       334
#    macro avg       0.50      0.35      0.42       334
# weighted avg       1.00      0.71      0.83       334
